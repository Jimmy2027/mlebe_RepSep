# %%
from utils import plot_reg_comparison

# %% [markdown]
# Run this notebook with
# ``jupyter nbconvert --to notebook --execute qualitative_reg_ev.ipynb && jupyter nbconvert --to html qualitative_reg_ev.ipynb``

# %%
plot_reg_comparison()
# Out:
# ****************************** sub-4013 ******************************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-4cab68c04d8a> in <module>
# ----> 1 plot_reg_comparison()
#
# ~/Documents/Python/mlebe_RepSep/manual_results_evaluation/utils.py in plot_reg_comparison()
#      43                     plt.axis('off')
#      44                     plt.subplot(1, 2, 2)
# ---> 45                     plt.imshow(volume_masked[:, slice, :], cmap='gray')
#      46                     plt.imshow(template_volume[:, slice, :], alpha=0.4, cmap='Blues')
#      47                     plt.axis('off')
#
# ~/opt/anaconda3/envs/mlebe/lib/python3.8/site-packages/nibabel/arrayproxy.py in __getitem__(self, slicer)
#     395
#     396     def __getitem__(self, slicer):
# --> 397         return self._get_scaled(dtype=None, slicer=slicer)
#     398
# ...
